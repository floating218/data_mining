# %%
mycolumns=[


'JUNCTION_CODE',

'BODY_TYPE_CODE',
'RD_COND_CODE',
'RD_DIV_CODE',
'SURF_COND_CODE',
]

# %%
import pandas as pd
#테이블 불러오기
df=pd.read_csv('maryland_accident_dataset_by_report_no.csv').set_index('REPORT_NO')

# %%
#df의 전처리



def return_df(df):

    #불필요한 id 데이터 삭제, person type은 D로 동일하므로 삭제
    df = df.drop(['PERSON_TYPE', 'PERSON_ID','VEHICLE_ID'], axis=1)

    #너무 치우친 데이터는 삭제.
    #df=df.drop(['RD_COND_CODE','SAF_EQUIP_CODE','EQUIP_PROB_CODE'],axis=1)

    #area_direction 처리.
    area_direction=list(df.AREA_DAMAGED_CODE_MAIN).copy()
    for i in range(len(area_direction)):
        if area_direction[i][:-8] in ['Eleven','Twelve','One']:
            area_direction[i]='front'
        elif area_direction[i][:-8] in ['Two','Three','Four']:
            area_direction[i]='right'
        elif area_direction[i][:-8] in ['Five','Six','Seven']:
            area_direction[i]='back'
        elif area_direction[i][:-8] in ['Eight','Nine','Ten']:
            area_direction[i]='left'
        else:
            area_direction[i]=area_direction[i]
    df['AREA_DAMAGED_CODE_MAIN']=area_direction

    #injury 평가를 위한 복사본 생성
    #y 변수 조정:fatal은 1, no injury는 0, 나머지는 0.5로 변경
    injury_str=list(df['INJ_SEVER_CODE'])
    for i in range(len(injury_str)):
        if injury_str[i]=='Fatal Injury':
            injury_str[i]=30.0
        elif injury_str[i]=='No Injury':
            injury_str[i]=0
        elif injury_str[i][0:3]=='Non':
            injury_str[i]=15
        else: 
            injury_str[i]=15
    df['INJURY']=injury_str 

    #month데이터는 그룹화해서 정리.
    months=list(map(lambda x:x[5]+x[6],df.TIME))
    for i in range(len(months)):
        if months[i][0]=='0':
            months[i]=int(months[i][1])
        else:
            months[i]=int(months[i])
    for i in range(len(months)):
        if months[i]<4:
            months[i]=0
        elif months[i]<7:
            months[i]=1
        elif months[i]<10:
            months[i]=2
        else:
            months[i]=3
    df['MONTH']=months

    ages=list(df.AGE)
    for i in range(len(ages)):
        if ages[i]<30:
            ages[i]=0
        elif ages[i]<40:
            ages[i]=1
        elif ages[i]<50:
            ages[i]=2
        elif ages[i]<60:
            ages[i]=3
        else:
            ages[i]=4
    df['AGE']=ages
    return df

def preprocess(df,col_list):
    
    #1.숫자 데이터를 뺀후
    p_df=df.copy()    
    num_columns=['TIME','AGE','INJURY','MONTH']
    p_df=p_df.drop(num_columns,axis=1)
    
    p_df=p_df[col_list]

    #2.나머지 데이터를 더미화한다
    dummies=list(p_df.columns)
    dummied = pd.get_dummies(p_df, columns=dummies)
    try:
        dummied=dummied.drop(['CDL_FLAG_N'],axis=1)
    except:
        pass
    try:
        dummied=dummied.drop(['FAULT_FLAG_N'],axis=1)
    except:
        pass
    try:
        dummied=dummied.drop(['HIT_AND_RUN_FLAG_N'],axis=1)
    except:
        pass
    try:
        dummied=dummied.drop(['C_M_ZONE_FLAG_N'],axis=1)
    except:
        pass
    p_df=dummied
    #--더미화한 후 별 의미 없는 컬럼은 삭제함.

    #4. 숫자변수 다시 넣기
    p_df['MONTH']=df['MONTH']
    p_df['AGE']=df['AGE']
    p_df['INJURY']=df['INJURY']

    #5. 숫자 데이터 표준화
    scalings=['AGE','MONTH','INJURY']
    p_df[scalings]=(p_df \
        [scalings]-p_df[scalings].min())\
        /(p_df[scalings].max()-\
          p_df[scalings].min())
        

    return p_df

from sklearn.cluster import KMeans
def k_means(p_df):
    n_cluster=3
    kmeans_model=KMeans(n_clusters=5)
    result_df=p_df.copy()
    
    p_df=p_df.drop(['INJURY'],axis=1)
    
    kmeans_model.fit(p_df)
    #kmeans_model.cluster_centers_ #113 차원의 경우, 113개의 무게중심 * 클러스터의수
    
    result_df['kmeans_labels']=kmeans_model.labels_
    return result_df

def show_analysis(result_df):
    analysis=result_df.groupby('kmeans_labels').mean()
    result_df.groupby('kmeans_labels').count()
    return analysis.transpose()

from sklearn.model_selection import train_test_split
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz


def datamining(df,col_list):
    p_df=return_df(df)
    p_df=preprocess(p_df,col_list)
    result_df=k_means(p_df)
    return (p_df,result_df,show_analysis(result_df))

# %%
a=datamining(df,mycolumns)
a[2]
# Out:
# kmeans_labels                                              0         1  \
# JUNCTION_CODE_Alley                                 0.000590  0.000475
# JUNCTION_CODE_Commercial Driveway                   0.012677  0.011552
# JUNCTION_CODE_Crossover Related                     0.014446  0.004589
# JUNCTION_CODE_Interchange Related                   0.014446  0.013451
# JUNCTION_CODE_Intersection                          0.000000  0.295616
# JUNCTION_CODE_Intersection Related                  0.177476  0.123121
# JUNCTION_CODE_Non Intersection                      0.777712  0.548188
# JUNCTION_CODE_Railway Grade Crossing                0.000884  0.000158
# JUNCTION_CODE_Residential Driveway                  0.001769  0.002849
# BODY_TYPE_CODE_(Sport) Utility Vehicle              0.416274  0.135306
# BODY_TYPE_CODE_All Terrain Vehicle (ATV)            0.002653  0.001424
# BODY_TYPE_CODE_Ambulance/Emergency                  0.004717  0.000791
# BODY_TYPE_CODE_Ambulance/Non Emergency              0.001769  0.000633
# BODY_TYPE_CODE_Cargo Van/Light Truck 2 axles (1...  0.028892  0.005697
# BODY_TYPE_CODE_Cross Country Bus                    0.000590  0.000000
# BODY_TYPE_CODE_Farm Vehicle                         0.000295  0.000000
# BODY_TYPE_CODE_Fire Vehicle/Emergency               0.003538  0.000317
# BODY_TYPE_CODE_Fire Vehicle/Non Emergency           0.002064  0.000317
# BODY_TYPE_CODE_Limousine                            0.000295  0.000000
# BODY_TYPE_CODE_Low Speed Vehicle                    0.001179  0.000317
# BODY_TYPE_CODE_Medium/Heavy Truck 2 axles (10,0...  0.027417  0.007438
# BODY_TYPE_CODE_Moped                                0.002653  0.000791
# BODY_TYPE_CODE_Motorcycle                           0.019163  0.001424
# BODY_TYPE_CODE_Other Bus                            0.009729  0.002690
# BODY_TYPE_CODE_Other Light Trucks (10,000 lbs (...  0.025059  0.010128
# BODY_TYPE_CODE_Passenger Car                        0.000000  0.673366
# BODY_TYPE_CODE_Pickup Truck                         0.163915  0.073746
# BODY_TYPE_CODE_Police Vehicle/Emergency             0.016509  0.006172
# BODY_TYPE_CODE_Police Vehicle/Non Emergency         0.018573  0.006805
# BODY_TYPE_CODE_Recreational Vehicle                 0.040684  0.008546
# ...                                                      ...       ...
# BODY_TYPE_CODE_Snowmobile                           0.000000  0.000000
# BODY_TYPE_CODE_Station Wagon                        0.017983  0.006488
# BODY_TYPE_CODE_Transit Bus                          0.031545  0.005855
# BODY_TYPE_CODE_Truck Tractor                        0.041274  0.011078
# BODY_TYPE_CODE_Van                                  0.105248  0.033233
# RD_COND_CODE_Foreign Material                       0.002948  0.003956
# RD_COND_CODE_Holes, Ruts, Etc.                      0.006486  0.006647
# RD_COND_CODE_Loose Surface Material                 0.003833  0.002057
# RD_COND_CODE_No Defects                             0.984965  0.984649
# RD_COND_CODE_Obstruction Not Lighted                0.000000  0.000791
# RD_COND_CODE_Obstruction Not Signaled               0.000295  0.000000
# RD_COND_CODE_Shoulder Defect                        0.001474  0.001108
# RD_COND_CODE_View Obstructed                        0.000000  0.000791
# RD_DIV_CODE_One-way Trafficway                      0.113208  0.077544
# RD_DIV_CODE_Two-way, Divided, Positive Median B...  0.697229  0.390252
# RD_DIV_CODE_Two-way, Divided, Unprotected (pain...  0.179540  0.113467
# RD_DIV_CODE_Two-way, Not Divided                    0.000000  0.412724
# RD_DIV_CODE_Two-way, Not Divided with a Continu...  0.010024  0.006014
# SURF_COND_CODE_Dry                                  0.946934  0.000000
# SURF_COND_CODE_Ice                                  0.022406  0.000000
# SURF_COND_CODE_Mud, Dirt, Gravel                    0.000590  0.000000
# SURF_COND_CODE_Oil                                  0.000590  0.000158
# SURF_COND_CODE_Sand                                 0.000000  0.000000
# SURF_COND_CODE_Slush                                0.003243  0.000000
# SURF_COND_CODE_Snow                                 0.026238  0.000000
# SURF_COND_CODE_Water (standing/moving)              0.000000  0.000000
# SURF_COND_CODE_Wet                                  0.000000  0.999842
# MONTH                                               0.592669  0.689719
# AGE                                                 0.455999  0.373635
# INJURY                                              0.068249  0.087909
#
# kmeans_labels                                              2         3  \
# JUNCTION_CODE_Alley                                 0.002150  0.000000
# JUNCTION_CODE_Commercial Driveway                   0.032253  0.000000
# JUNCTION_CODE_Crossover Related                     0.001997  0.000000
# JUNCTION_CODE_Interchange Related                   0.002765  0.000000
# JUNCTION_CODE_Intersection                          0.000000  1.000000
# JUNCTION_CODE_Intersection Related                  0.181693  0.000000
# JUNCTION_CODE_Non Intersection                      0.765013  0.000000
# JUNCTION_CODE_Railway Grade Crossing                0.000922  0.000000
# JUNCTION_CODE_Residential Driveway                  0.013208  0.000000
# BODY_TYPE_CODE_(Sport) Utility Vehicle              0.151743  0.141254
# BODY_TYPE_CODE_All Terrain Vehicle (ATV)            0.001536  0.000701
# BODY_TYPE_CODE_Ambulance/Emergency                  0.001382  0.001403
# BODY_TYPE_CODE_Ambulance/Non Emergency              0.000768  0.000140
# BODY_TYPE_CODE_Cargo Van/Light Truck 2 axles (1...  0.009522  0.005751
# BODY_TYPE_CODE_Cross Country Bus                    0.000000  0.000000
# BODY_TYPE_CODE_Farm Vehicle                         0.000614  0.000000
# BODY_TYPE_CODE_Fire Vehicle/Emergency               0.002611  0.001262
# BODY_TYPE_CODE_Fire Vehicle/Non Emergency           0.001075  0.000281
# BODY_TYPE_CODE_Limousine                            0.000154  0.000140
# BODY_TYPE_CODE_Low Speed Vehicle                    0.000000  0.000842
# BODY_TYPE_CODE_Medium/Heavy Truck 2 axles (10,0...  0.009676  0.005471
# BODY_TYPE_CODE_Moped                                0.001075  0.000561
# BODY_TYPE_CODE_Motorcycle                           0.013516  0.006873
# BODY_TYPE_CODE_Other Bus                            0.002150  0.003507
# BODY_TYPE_CODE_Other Light Trucks (10,000 lbs (...  0.013208  0.010801
# BODY_TYPE_CODE_Passenger Car                        0.601597  0.674569
# BODY_TYPE_CODE_Pickup Truck                         0.083090  0.054987
# BODY_TYPE_CODE_Police Vehicle/Emergency             0.010444  0.005751
# BODY_TYPE_CODE_Police Vehicle/Non Emergency         0.017048  0.009398
# BODY_TYPE_CODE_Recreational Vehicle                 0.004300  0.004068
# ...                                                      ...       ...
# BODY_TYPE_CODE_Snowmobile                           0.000461  0.000140
# BODY_TYPE_CODE_Station Wagon                        0.009062  0.008276
# BODY_TYPE_CODE_Transit Bus                          0.011365  0.011362
# BODY_TYPE_CODE_Truck Tractor                        0.007219  0.005471
# BODY_TYPE_CODE_Van                                  0.035939  0.037593
# RD_COND_CODE_Foreign Material                       0.005068  0.001403
# RD_COND_CODE_Holes, Ruts, Etc.                      0.004915  0.002665
# RD_COND_CODE_Loose Surface Material                 0.006451  0.001403
# RD_COND_CODE_No Defects                             0.981570  0.992285
# RD_COND_CODE_Obstruction Not Lighted                0.000154  0.000000
# RD_COND_CODE_Obstruction Not Signaled               0.000000  0.000140
# RD_COND_CODE_Shoulder Defect                        0.001382  0.000982
# RD_COND_CODE_View Obstructed                        0.000461  0.001122
# RD_DIV_CODE_One-way Trafficway                      0.000000  0.072801
# RD_DIV_CODE_Two-way, Divided, Positive Median B...  0.000000  0.336934
# RD_DIV_CODE_Two-way, Divided, Unprotected (pain...  0.000000  0.129752
# RD_DIV_CODE_Two-way, Not Divided                    1.000000  0.451957
# RD_DIV_CODE_Two-way, Not Divided with a Continu...  0.000000  0.008557
# SURF_COND_CODE_Dry                                  0.918906  0.973769
# SURF_COND_CODE_Ice                                  0.039625  0.009959
# SURF_COND_CODE_Mud, Dirt, Gravel                    0.001229  0.000421
# SURF_COND_CODE_Oil                                  0.000307  0.000000
# SURF_COND_CODE_Sand                                 0.000154  0.000000
# SURF_COND_CODE_Slush                                0.006143  0.002805
# SURF_COND_CODE_Snow                                 0.032714  0.012765
# SURF_COND_CODE_Water (standing/moving)              0.000922  0.000281
# SURF_COND_CODE_Wet                                  0.000000  0.000000
# MONTH                                               0.561921  0.593959
# AGE                                                 0.382967  0.407561
# INJURY                                              0.095454  0.098471
#
# kmeans_labels                                              4
# JUNCTION_CODE_Alley                                 0.000481
# JUNCTION_CODE_Commercial Driveway                   0.012176
# JUNCTION_CODE_Crossover Related                     0.009452
# JUNCTION_CODE_Interchange Related                   0.017142
# JUNCTION_CODE_Intersection                          0.000000
# JUNCTION_CODE_Intersection Related                  0.186479
# JUNCTION_CODE_Non Intersection                      0.772349
# JUNCTION_CODE_Railway Grade Crossing                0.000160
# JUNCTION_CODE_Residential Driveway                  0.001762
# BODY_TYPE_CODE_(Sport) Utility Vehicle              0.000000
# BODY_TYPE_CODE_All Terrain Vehicle (ATV)            0.000000
# BODY_TYPE_CODE_Ambulance/Emergency                  0.000000
# BODY_TYPE_CODE_Ambulance/Non Emergency              0.000000
# BODY_TYPE_CODE_Cargo Van/Light Truck 2 axles (1...  0.000000
# BODY_TYPE_CODE_Cross Country Bus                    0.000000
# BODY_TYPE_CODE_Farm Vehicle                         0.000000
# BODY_TYPE_CODE_Fire Vehicle/Emergency               0.000000
# BODY_TYPE_CODE_Fire Vehicle/Non Emergency           0.000000
# BODY_TYPE_CODE_Limousine                            0.000000
# BODY_TYPE_CODE_Low Speed Vehicle                    0.000000
# BODY_TYPE_CODE_Medium/Heavy Truck 2 axles (10,0...  0.000000
# BODY_TYPE_CODE_Moped                                0.000000
# BODY_TYPE_CODE_Motorcycle                           0.000000
# BODY_TYPE_CODE_Other Bus                            0.000000
# BODY_TYPE_CODE_Other Light Trucks (10,000 lbs (...  0.000000
# BODY_TYPE_CODE_Passenger Car                        1.000000
# BODY_TYPE_CODE_Pickup Truck                         0.000000
# BODY_TYPE_CODE_Police Vehicle/Emergency             0.000000
# BODY_TYPE_CODE_Police Vehicle/Non Emergency         0.000000
# BODY_TYPE_CODE_Recreational Vehicle                 0.000000
# ...                                                      ...
# BODY_TYPE_CODE_Snowmobile                           0.000000
# BODY_TYPE_CODE_Station Wagon                        0.000000
# BODY_TYPE_CODE_Transit Bus                          0.000000
# BODY_TYPE_CODE_Truck Tractor                        0.000000
# BODY_TYPE_CODE_Van                                  0.000000
# RD_COND_CODE_Foreign Material                       0.005287
# RD_COND_CODE_Holes, Ruts, Etc.                      0.004646
# RD_COND_CODE_Loose Surface Material                 0.001442
# RD_COND_CODE_No Defects                             0.986863
# RD_COND_CODE_Obstruction Not Lighted                0.000000
# RD_COND_CODE_Obstruction Not Signaled               0.000000
# RD_COND_CODE_Shoulder Defect                        0.001282
# RD_COND_CODE_View Obstructed                        0.000481
# RD_DIV_CODE_One-way Trafficway                      0.118552
# RD_DIV_CODE_Two-way, Divided, Positive Median B...  0.691285
# RD_DIV_CODE_Two-way, Divided, Unprotected (pain...  0.180070
# RD_DIV_CODE_Two-way, Not Divided                    0.000000
# RD_DIV_CODE_Two-way, Not Divided with a Continu...  0.010093
# SURF_COND_CODE_Dry                                  0.961070
# SURF_COND_CODE_Ice                                  0.016982
# SURF_COND_CODE_Mud, Dirt, Gravel                    0.000320
# SURF_COND_CODE_Oil                                  0.000481
# SURF_COND_CODE_Sand                                 0.000000
# SURF_COND_CODE_Slush                                0.003685
# SURF_COND_CODE_Snow                                 0.017142
# SURF_COND_CODE_Water (standing/moving)              0.000320
# SURF_COND_CODE_Wet                                  0.000000
# MONTH                                               0.611289
# AGE                                                 0.367550
# INJURY                                              0.075857
#
# [61 rows x 5 columns]

# %%
#decision tree 확인 용 코드

p_df=a[0]
result_df=a[1]

X,y=result_df.drop('kmeans_labels',axis=1),result_df.kmeans_labels
#train,test
X_train,X_test,y_train,y_test=train_test_split\
(X,y,test_size=0.25,random_state=77,stratify=y)
dt_model=DecisionTreeClassifier(class_weight='balanced',min_samples_leaf=100,max_depth=6) 
dt_model.fit(X=X,y=y)
dt_model.predict(X=X_test)#시리즈
dt_model.score(X=X_test,y=y_test) #정답률. 성능이 많이 떨어짐
cluster_names=['0','1','2','3','4']
with open('test_tree.dot','w') as f:
    export_graphviz(dt_model,f,feature_names=X.columns,class_names=cluster_names)
with open('test_tree.dot','r') as f:
    dot_graph=f.read()
dot_graph
graphviz.Source(dot_graph)

# %%
result_df
w=pd.ExcelWriter('통합6_result_df.xlsx')
a[1].to_excel(w)
w.save()
